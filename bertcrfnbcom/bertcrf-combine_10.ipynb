# %%
# !pip install -r /kaggle/input/bert-crfcom/bertcrfnbcom/requirements.txt -q

# %%
import torch.cuda
import sys
sys.path.insert(0, '/kaggle/input/bert-crfcom/bertcrfnbcom')
from re_utils.train import train_ner

# %%
num_labels = 63
train_tokenized_texts_path = "/kaggle/input/bert-crfcom/bertcrfnbcom/resources/data/train/train_processed_id_10.jsonl"
test_tokenized_texts_path = "/kaggle/input/bert-crfcom/bertcrfnbcom/resources/data/test/test_processed_id.jsonl"
dropout = 0.2
batch_size = 32
epochs = 3
log_every = 100
lr_new_layers = 1e-3
lr_bert = 1e-5
device = "cuda" if torch.cuda.is_available() else "cpu"
print(device)
# Out:
# cuda

# %%
# bert-base-cased w/o crf

train_ner(
    num_labels=num_labels,
    bert_name="bert-base-cased",
    train_tokenized_texts_path=train_tokenized_texts_path,
    test_tokenized_texts_path=test_tokenized_texts_path,
    dropout=dropout,
    batch_size=batch_size,
    epochs=epochs,
    log_every=log_every,
    lr_new_layers=lr_new_layers,
    lr_bert=lr_bert,
    use_crf=False,
    save_to=None,
    device=device
)
# Out:
# Current loss: 0.5306112766265869
# f1_micro: [0.8946242320042769]
# f1_macro: [0.13344786914193438]
# mcc: [0.629739078459588]
# /opt/conda/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /opt/conda/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00       359
#            1       0.43      0.35      0.39      3609
#            2       0.00      0.00      0.00       723
#            3       0.00      0.00      0.00       209
#            4       0.71      0.88      0.79      8621
#            5       0.00      0.00      0.00       428
#            6       0.00      0.00      0.00       607
#            7       0.00      0.00      0.00       342
#            8       0.00      0.00      0.00       516
#            9       0.00      0.00      0.00       435
#           10       0.00      0.00      0.00        59
#           11       0.00      0.00      0.00       607
#           12       0.50      0.00      0.01      3452
#           13       0.31      0.20      0.24      5259
#           14       0.00      0.00      0.00       180
#           15       0.16      0.04      0.07      1102
#           16       0.68      0.02      0.05      2256
#           17       0.00      0.00      0.00       204
#           18       0.46      0.03      0.06      3208
#           19       0.00      0.00      0.00        91
#           20       1.00      0.00      0.00      1326
#           21       0.48      0.49      0.49     11399
#           22       0.84      0.66      0.74      6085
#           23       0.00      0.00      0.00       180
#           24       0.00      0.00      0.00      1386
#           25       0.62      0.03      0.05      1188
#           26       0.76      0.14      0.24       115
#           27       0.38      0.04      0.07      2346
#           28       0.00      0.00      0.00       283
#           29       0.67      0.91      0.77       405
#           30       0.35      0.04      0.07      4643
#           31       0.00      0.00      0.00       810
#           32       0.43      0.22      0.30      2119
#           33       0.00      0.00      0.00       628
#           34       0.00      0.00      0.00       399
#           35       0.95      0.86      0.90     24952
#           36       0.00      0.00      0.00       831
#           37       0.00      0.00      0.00      1046
#           38       0.00      0.00      0.00       459
#           39       0.00      0.00      0.00       671
#           40       0.00      0.00      0.00       341
#           41       0.00      0.00      0.00       288
#           42       0.00      0.00      0.00      1489
#           43       0.86      0.33      0.48     14408
#           44       0.43      0.10      0.17      9375
#           45       0.00      0.00      0.00       121
#           46       0.00      0.00      0.00       329
#           47       0.00      0.00      0.00       731
#           48       0.00      0.00      0.00       100
#           49       0.00      0.00      0.00      3076
#           50       0.00      0.00      0.00        51
#           51       0.90      0.05      0.09      1521
#           52       0.59      0.83      0.69     20642
#           53       0.86      0.69      0.77      3551
#           54       0.00      0.00      0.00       172
#           55       0.00      0.00      0.00       547
#           56       0.00      0.00      0.00       784
#           57       0.00      0.00      0.00        33
#           58       0.30      0.00      0.01       980
#           59       0.00      0.00      0.00       203
#           60       0.00      0.00      0.00        47
#           61       0.42      0.01      0.03      2673
#           62       0.92      0.99      0.96    711053
#
#     accuracy                           0.89    866053
#    macro avg       0.24      0.13      0.13    866053
# weighted avg       0.86      0.89      0.87    866053
# /opt/conda/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
# bert-base-cased + crf

train_ner(
    num_labels=num_labels,
    bert_name="bert-base-cased",
    train_tokenized_texts_path=train_tokenized_texts_path,
    test_tokenized_texts_path=test_tokenized_texts_path,
    dropout=dropout,
    batch_size=batch_size,
    epochs=epochs,
    log_every=log_every,
    lr_new_layers=lr_new_layers,
    lr_bert=lr_bert,
    use_crf=True,
    save_to=None,
    device=device
)
# Out:
# Current loss: 12.23810863494873
# f1_micro: [0.8969139302098138]
# f1_macro: [0.15549494339944345]
# mcc: [0.6446272206757523]
# /opt/conda/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00       359
#            1       0.59      0.29      0.39      3609
#            2       0.00      0.00      0.00       723
#            3       0.00      0.00      0.00       209
#            4       0.75      0.86      0.80      8621
#            5       0.00      0.00      0.00       428
#            6       0.00      0.00      0.00       607
#            7       0.00      0.00      0.00       342
#            8       0.00      0.00      0.00       516
#            9       0.00      0.00      0.00       435
#           10       0.00      0.00      0.00        59
#           11       0.00      0.00      0.00       607
#           12       0.80      0.13      0.22      3452
#           13       0.28      0.28      0.28      5259
#           14       0.00      0.00      0.00       180
#           15       0.31      0.03      0.06      1102
#           16       0.45      0.01      0.01      2256
#           17       0.00      0.00      0.00       204
#           18       0.43      0.06      0.11      3208
#           19       0.00      0.00      0.00        91
#           20       0.00      0.00      0.00      1326
#           21       0.54      0.46      0.50     11399
#           22       0.73      0.71      0.72      6085
#           23       0.00      0.00      0.00       180
#           24       0.85      0.05      0.09      1386
#           25       0.54      0.08      0.14      1188
#           26       0.76      0.38      0.51       115
#           27       0.34      0.16      0.22      2346
#           28       0.00      0.00      0.00       283
#           29       0.77      0.72      0.74       405
#           30       0.27      0.21      0.23      4643
#           31       0.00      0.00      0.00       810
#           32       0.34      0.37      0.35      2119
#           33       0.00      0.00      0.00       628
#           34       0.00      0.00      0.00       399
#           35       0.93      0.89      0.91     24952
#           36       1.00      0.00      0.00       831
#           37       0.00      0.00      0.00      1046
#           38       0.00      0.00      0.00       459
#           39       0.00      0.00      0.00       671
#           40       0.00      0.00      0.00       341
#           41       0.00      0.00      0.00       288
#           42       0.00      0.00      0.00      1489
#           43       0.86      0.46      0.60     14408
#           44       0.39      0.01      0.02      9375
#           45       0.00      0.00      0.00       121
#           46       0.00      0.00      0.00       329
#           47       0.00      0.00      0.00       731
#           48       0.00      0.00      0.00       100
#           49       0.00      0.00      0.00      3076
#           50       0.00      0.00      0.00        51
#           51       0.55      0.08      0.14      1521
#           52       0.55      0.88      0.67     20642
#           53       0.88      0.70      0.78      3551
#           54       0.00      0.00      0.00       172
#           55       0.00      0.00      0.00       547
#           56       0.00      0.00      0.00       784
#           57       0.00      0.00      0.00        33
#           58       0.57      0.24      0.34       980
#           59       0.00      0.00      0.00       203
#           60       0.00      0.00      0.00        47
#           61       0.00      0.00      0.00      2673
#           62       0.93      0.99      0.96    711053
#
#     accuracy                           0.90    866053
#    macro avg       0.24      0.14      0.16    866053
# weighted avg       0.86      0.90      0.87    866053
# /opt/conda/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /opt/conda/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
